# %%
# numerical calculation & data frames
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so

# statistics
import statsmodels.api as sm

# pandas options
pd.set_option('mode.copy_on_write', True)  # pandas 2.0
pd.options.display.float_format = '{:.2f}'.format  # pd.reset_option('display.float_format')
pd.options.display.max_rows = 7  # max number of rows to display

# NumPy options
np.set_printoptions(precision = 2, suppress=True)  # suppress scientific notation

# For high resolution display
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats("retina")

# %%
df1 = pd.read_csv("C:/Users\yykyy/Downloads/교통사고 구급출동 현황.csv")
df2 = pd.read_csv("C:/Users\yykyy/Downloads/교통사고 구급출동 현황_2021.csv")
df3 = pd.read_csv("C:/Users\yykyy/Downloads/교통사고 구급출동 현황_2011_2020.csv")
# Out:
# C:\Users\yykyy\AppData\Local\Temp\ipykernel_15368\309877728.py:1: DtypeWarning: Columns (86,87,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("C:/Users\yykyy/Downloads/교통사고 구급출동 현황.csv")
# C:\Users\yykyy\AppData\Local\Temp\ipykernel_15368\309877728.py:2: DtypeWarning: Columns (84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("C:/Users\yykyy/Downloads/교통사고 구급출동 현황_2021.csv")
# C:\Users\yykyy\AppData\Local\Temp\ipykernel_15368\309877728.py:3: DtypeWarning: Columns (9,84,85,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv("C:/Users\yykyy/Downloads/교통사고 구급출동 현황_2011_2020.csv")

# %%
df1
# Out:
#          relif_reprt_no reg_cmptn_se_nm patnt_ocrn_type_se_nm  \
# 0     20224511302M00001            등록완료                   질병외
# 1     20224514401M00001            등록완료                   질병외
# 2     20224514401M00002            등록완료                   질병외
# ...                 ...             ...                   ...
# 8827  20224508304M00971            등록완료                   질병외
# 8828  20224503103M02612            등록완료                   질병외
# 8829  20224501102M03422            등록완료                   질병외
#
#      trnsport_acdnt_nm trnsport_acdnt_etc_nm frstt_nm      ward_nm  \
# 0                  운전자                   NaN    완주소방서    삼례119안전센터
# 1                  동승자                   NaN    장수소방서  무주119안전센터_신
# 2                  운전자                   NaN    장수소방서  무주119안전센터_신
# ...                ...                   ...      ...          ...
# 8827               동승자                   NaN    고창소방서    무장119안전센터
# ...

# %%
df2
# Out:
#          relif_reprt_no reg_cmptn_se_nm patnt_ocrn_type_se_nm  \
# 0     20214507101M00003            등록완료                   질병외
# 1     20214504107M00001            등록완료                   질병외
# 2     20214504305M00001            등록완료                   질병외
# ...                 ...             ...                   ...
# 8370  20214502106M03506            등록완료                   질병외
# 8371  20214508101M02436            등록완료                   질병외
# 8372  20214501101M06467            등록완료                   질병외
#
#      trnsport_acdnt_nm trnsport_acdnt_etc_nm frstt_nm    ward_nm  lfdau_nm  \
# 0                  운전자                   NaN    김제소방서  교동119안전센터       NaN
# 1                  운전자                   NaN    익산소방서  함열119안전센터       NaN
# 2                  운전자                   NaN    익산소방서  함열119안전센터  망성119지역대
# ...                ...                   ...      ...        ...       ...
# 8370               보행자                   NaN  전주완산소방서  평화119안전센터       NaN
# ...

# %%
df3.rename(columns={'qu_se': 'qtr_se'}, inplace=True)

# %%
df3 = df3[df3['dclr_yr'] == 2020]

# %%
df = pd.concat([df1,df2,df3])

# %%
df_new = df[(df['sigungu_nm'].str.startswith('전주시'))]

# %%
df_new
# Out:
#            relif_reprt_no reg_cmptn_se_nm patnt_ocrn_type_se_nm  \
# 0       20224511302M00001            등록완료                   질병외
# 5       20224501101M00006            등록완료                   질병외
# 6       20224501102M00004            등록완료                   질병외
# ...                   ...             ...                   ...
# 110369  20204502102M04996            등록완료                   질병외
# 110370  20204501105M02811            등록완료                   질병외
# 110379  20204502104M02966            등록완료                   질병외
#
#        trnsport_acdnt_nm trnsport_acdnt_etc_nm frstt_nm    ward_nm lfdau_nm  \
# 0                    운전자                   NaN    완주소방서  삼례119안전센터      NaN
# 5                 오토바이사고                   NaN  전주덕진소방서  금암119안전센터      NaN
# 6                 오토바이사고                   NaN  전주덕진소방서  팔복119안전센터      NaN
# ...                  ...                   ...      ...        ...      ...
# ...

# %%
coldf = pd.read_csv("C:/Users/yykyy/Downloads/교통사고 구급출동 현황_sample.csv")
coldf
# Out:
#               구급보고서번호          등록완료구분명              환자발생유형구분명  \
# 0     ﻿relif_reprt_no  reg_cmptn_se_nm  patnt_ocrn_type_se_nm
# 1   20224511302M00001             등록완료                    질병외
# 2   20224514401M00001             등록완료                    질병외
# ..                ...              ...                    ...
# 16  20224511401M00003             등록완료                    질병외
# 17  20224503310M00003             등록완료                    질병외
# 18  20224503310M00004             등록완료                    질병외
#
#                 교통사고명                교통사고기타명      소방서명         서센터명  \
# 0   trnsport_acdnt_nm  trnsport_acdnt_etc_nm  frstt_nm      ward_nm
# 1                 운전자                    NaN     완주소방서    삼례119안전센터
# 2                 동승자                    NaN     장수소방서  무주119안전센터_신
# ..                ...                    ...       ...          ...
# 16                운전자                    NaN     완주소방서    봉동119안전센터
# ...

# %%
coldf.columns
# Out:
# Index(['구급보고서번호', '등록완료구분명', '환자발생유형구분명', '교통사고명', '교통사고기타명', '소방서명', '서센터명',
#        '소방지역대명', '구급활동구분명', '헬리콥터펌뷸런스유무명',
#        ...
#        '현장거리2', '재이송사유2', '이송분류명', '이송분류사유', '시간단위기온', '시간단위강수량', '시간단위풍속',
#        '시간단위풍향', '시간단위습도', '시간단위적설량'],
#       dtype='object', length=102)

# %%
df_new.columns = coldf.columns

# %%
df_new
# Out:
#                   구급보고서번호 등록완료구분명 환자발생유형구분명   교통사고명 교통사고기타명     소방서명  \
# 0       20224511302M00001    등록완료       질병외     운전자     NaN    완주소방서
# 5       20224501101M00006    등록완료       질병외  오토바이사고     NaN  전주덕진소방서
# 6       20224501102M00004    등록완료       질병외  오토바이사고     NaN  전주덕진소방서
# ...                   ...     ...       ...     ...     ...      ...
# 110369  20204502102M04996    등록완료       질병외  오토바이사고     NaN  전주완산소방서
# 110370  20204501105M02811    등록완료       질병외     보행자     NaN  전주덕진소방서
# 110379  20204502104M02966    등록완료       질병외     보행자     NaN  전주완산소방서
#
#              서센터명 소방지역대명 구급활동구분명 헬리콥터펌뷸런스유무명  ...  현장거리2  재이송사유2  이송분류명  \
# 0       삼례119안전센터    NaN    특수일반         NaN  ...    NaN     NaN     이송
# 5       금암119안전센터    NaN    특수일반         NaN  ...    NaN     NaN     이송
# 6       팔복119안전센터    NaN    특수일반         NaN  ...    NaN     NaN     이송
# ...           ...    ...     ...         ...  ...    ...     ...    ...
# ...

# %%
df_new['시군구명']
# Out:
# 0         전주시덕진구
# 5         전주시덕진구
# 6         전주시완산구
#            ...
# 110369    전주시완산구
# 110370    전주시덕진구
# 110379    전주시덕진구
# Name: 시군구명, Length: 6740, dtype: object

# %%
df_new.to_csv("C:/동국대학교/공모전/전주공모전/구급출동_전주_2020_2022.csv", encoding='cp949', index=False)

# %%
df_new
# Out:
#                   구급보고서번호 등록완료구분명 환자발생유형구분명   교통사고명 교통사고기타명     소방서명  \
# 0       20224511302M00001    등록완료       질병외     운전자     NaN    완주소방서
# 5       20224501101M00006    등록완료       질병외  오토바이사고     NaN  전주덕진소방서
# 6       20224501102M00004    등록완료       질병외  오토바이사고     NaN  전주덕진소방서
# ...                   ...     ...       ...     ...     ...      ...
# 110369  20204502102M04996    등록완료       질병외  오토바이사고     NaN  전주완산소방서
# 110370  20204501105M02811    등록완료       질병외     보행자     NaN  전주덕진소방서
# 110379  20204502104M02966    등록완료       질병외     보행자     NaN  전주완산소방서
#
#              서센터명 소방지역대명 구급활동구분명 헬리콥터펌뷸런스유무명  ...  현장거리2  재이송사유2  이송분류명  \
# 0       삼례119안전센터    NaN    특수일반         NaN  ...    NaN     NaN     이송
# 5       금암119안전센터    NaN    특수일반         NaN  ...    NaN     NaN     이송
# 6       팔복119안전센터    NaN    특수일반         NaN  ...    NaN     NaN     이송
# ...           ...    ...     ...         ...  ...    ...     ...    ...
# ...
